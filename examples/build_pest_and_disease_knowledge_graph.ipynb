# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv("/Users/mac/Documents/PHUNGPX/knowledge_graph_searching/.env")

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

MODEL_NAME = "gpt-4.1-mini"

if "NEO4J_URI" not in os.environ:
    os.environ["NEO4J_URI"] = getpass.getpass("Enter your Neo4j URI: ")

if "NEO4J_USERNAME" not in os.environ:
    os.environ["NEO4J_USERNAME"] = getpass.getpass("Enter your Neo4j username: ")

if "NEO4J_PASSWORD" not in os.environ:
    os.environ["NEO4J_PASSWORD"] = getpass.getpass("Enter your Neo4j password: ")

# %%
import pandas as pd
from langchain_neo4j import Neo4jGraph

graph = Neo4jGraph(
    url=os.getenv("NEO4J_URI"),
    username=os.getenv("NEO4J_USERNAME"),
    password=os.getenv("NEO4J_PASSWORD"),
)

# %%
def load_excel(
    file_path: str,
    sheet_name: str,
    ignored_column_names: list[str] = None
) -> list[str]:
    if ignored_column_names is None:
        ignored_column_names = []

    df = pd.read_excel(file_path, sheet_name=sheet_name)

    row_infos = []
    for _, row in df.iterrows():
        text_parts = []

        column_id = 0
        for column in df.columns:
            if column in ignored_column_names:
                continue

            if pd.notna(row[column]) and str(row[column]).strip():
                column_id += 1
                text_parts.append(f"{column_id}. `{column}`: {row[column]}")

        full_text = "\n".join(text_parts)

        row_infos.append(full_text)

    return row_infos

# %%
documents = load_excel(
    file_path="/Users/mac/Documents/PHUNGPX/knowledge_graph_searching/data/durian_pest_and_disease_data.xlsx",
    sheet_name="(3) Diseases Information",
    ignored_column_names=["No.", "References"]
)

# %%
print(documents[1])
# Out:
# 1. `English Name`: Pink Disease
# 2. `Vietnamese Name`: Bệnh nấm hồng
# 3. `Thailand Name`: โรคราสีชมพู (Rok Ra Si Chomphu)
# 4. `Scientific Name`: Erythricium salmonicolor (Berk. & Broome) Burds. [Teleomorph]. The anamorph is Necator salmonicolor Berk. & Broome. Identification is confirmed.
# 5. `Alternative Names`: Corticium salmonicolor (older synonym), Branch Canker, Stem Canker, Cobweb Disease, Penyakit Kulapuk Merah Jambu (Malay), Cendawan Angin (Malay)
# 6. `Description`: Pink Disease is a severe biotic fungal disease affecting the woody stems and branches of durian trees. Caused by the fungus Erythricium salmonicolor, it is one of the most significant branch and trunk diseases in durian, especially in high-rainfall tropical regions. The disease manifests as a crust-like fungal growth that girdles branches, leading to rapid dieback and, in severe cases on the main trunk of young trees, tree mortality. Its wide host range, including rubber, cacao, and coffee, makes it a persistent threat in diversified agricultural landscapes. The economic impact is substantial due to loss of productive branches, reduced fruit yield, and increased management costs for pruning and chemical treatment.
# 7. `Symptoms`: Symptoms primarily appear on the bark of branches, forks, and the main trunk.
# 1.  **Initial Stage (Cobweb Stage):** The first sign is the appearance of white, silky mycelial threads resembling a spider's web on the bark surface, often starting at branch crotches where moisture accumulates. This stage is often overlooked.
# 2.  **Intermediate Stage (Pustule Stage):** Small, orange-red pustules may form, which are stromata of the asexual stage (*Necator salmonicolor*).
# 3.  **Advanced Stage (Pink Crust Stage):** The white mycelium thickens and develops a distinct salmon-pink to bright orange-pink crust during wet conditions. This is the sporulating basidiocarp (teleomorph stage) of the fungus. The crust may be smooth or slightly cracked and becomes pale pink to greyish-white when dry.
# 4.  **Bark and Wood Damage:** The fungus penetrates the bark, causing it to crack, split, and sometimes exude gum. The underlying cambium and wood are killed, resulting in a canker that girdles the branch.
# 5.  **Foliar Symptoms:** Leaves on the infected branch turn yellow, wilt, dry up, and die but typically remain attached to the branch for an extended period. This 'flagging' is a key diagnostic symptom visible from a distance.
#
# **Diagnostic Methods:**
# *   **Visual:** The most reliable field diagnosis is the presence of the characteristic pink fungal crust on a branch coupled with the dieback of the distal part of that branch.
# *   **Microscopy:** Laboratory confirmation involves microscopic examination of the pink crust to identify the characteristic basidia and smooth, hyaline basidiospores of *E. salmonicolor*.
# 8. `Effect`: The disease has debilitating effects on both tree health and fruit production.
# *   **Tree Health:** The primary effect is branch dieback caused by the girdling action of the fungus. Infection of major scaffold limbs can drastically reduce the tree's photosynthetic capacity and structural integrity. If the main trunk of a young tree (under 10 years old) is infected, it can lead to the death of the entire tree. Overall tree vigor is significantly reduced.
# *   **Fruit Production:** Infection of fruiting branches leads to the cessation of nutrient flow, causing premature fruit drop, reduced fruit size, and poor fruit quality. While the fungus does not directly infect the fruit, the loss of productive branches results in direct and long-term yield loss. There are no specific post-harvest issues associated with this disease as its impact is pre-harvest.
# 9. `Causes`: The disease is caused by a pathogen under specific environmental conditions.
# *   **Primary Pathogen:** The basidiomycete fungus *Erythricium salmonicolor*.
# *   **Contributing Conditions (Indirect Triggers):**
#     *   **High Humidity:** Relative humidity above 80-85% is critical for fungal growth and sporulation.
#     *   **Prolonged Wetness:** Frequent and heavy rainfall, dew, and fog that keep branch surfaces wet for extended periods are the primary drivers of infection.
#     *   **Poor Air Circulation:** A dense canopy creates a humid microclimate that favors the pathogen.
# 10. `Spread Method`: The pathogen spreads effectively through several means:
# *   **Airborne Spores:** The pink crust produces vast numbers of basidiospores that are readily dispersed by wind over long distances.
# *   **Rain Splash:** Raindrops can splash spores and mycelial fragments onto adjacent branches or nearby trees, facilitating localized spread.
# *   **Contaminated Tools:** Pruning saws, shears, and other tools can carry fungal inoculum from infected to healthy trees if not properly sterilized.
# *   **Survival:** The fungus survives as dormant mycelium within infected bark cankers and on dead, attached branches. It can also persist on numerous alternative host plants in and around the orchard.
# 11. `Risk Factors`: *   **Climatic Factors:** The disease is most severe during the monsoon or rainy season. Regions with high annual rainfall (>2000 mm) are at high risk.
# *   **Agronomic Practices:**
#     *   **Dense Planting:** Close spacing between trees reduces airflow and sunlight penetration, trapping moisture in the canopy.
#     *   **Poor Pruning:** Failure to prune regularly results in a dense, bushy canopy with many crossing branches and water sprouts, which are ideal sites for infection.
#     *   **Over-fertilization (Nitrogen):** Excessive nitrogen application promotes lush, dense foliage, exacerbating the humid microclimate within the canopy.
# *   **Orchard Topography:** Orchards located in low-lying areas, valleys, or areas with poor air drainage are more susceptible.
# *   **Tree Age:** While it can affect trees of all ages, it is often more damaging to young, vigorous trees (3-10 years old) due to their dense canopies and thinner bark.
# 12. `Affected Varieties`: Most commercial durian cultivars are considered susceptible to Pink Disease. There is little evidence of significant genetic resistance in major cultivated varieties. Susceptibility is strongly influenced by canopy architecture and orchard management practices. Cultivars known to be affected include:
# *   **Monthong (D159):** Highly susceptible, widely reported.
# *   **Musang King (D197):** Susceptible.
# *   **Chanee (D123):** Susceptible.
# *   **Ri6:** Susceptible.
# *   **D24 (Sultan):** Susceptible.
# *   **Kanyao (D158):** Susceptible.
# Management practices, particularly canopy management through pruning, are more critical for disease control than cultivar selection.
# 13. `Seasonality`: Disease incidence and severity are highest during the peak of the rainy season, typically corresponding to the monsoon periods in Southeast Asia. Outbreaks are triggered by several consecutive days of rain, high humidity, and overcast skies. The risk is high during periods of active vegetative growth when the canopy is at its densest.
# 14. `Treatment`: A combination of mechanical and chemical methods is required for effective treatment.
# 1.  **Mechanical Control:**
#     *   **Pruning:** For infected branches, prune at least 40-50 cm below the last visible sign of infection. Paint the wound with a fungicidal paste.
#     *   **Scraping:** For infections on the main trunk or large, irreplaceable limbs, carefully scrape off the pink fungal crust and a thin layer of the underlying bark. Be careful not to damage the cambium excessively.
# 2.  **Chemical Control:**
#     *   **Fungicidal Pastes:** After pruning or scraping, apply a thick paste of a fungicide to the affected area. Common formulations include:
#         *   **Bordeaux Mixture:** Mix copper sulfate and hydrated lime. Apply as a paste.
#         *   **Copper Oxychloride:** Mix the powder with water to form a thick slurry.
#         *   **Systemic Fungicides:** Mix products containing active ingredients like hexaconazole, propiconazole, or tebuconazole with water or a sealant like latex paint to improve adherence and persistence.
#         *   **Calixin (Tridemorph):** An older but sometimes recommended fungicide, often mixed with a sealant.
#     *   **Foliar/Branch Sprays:** During high-risk periods, spraying the trunk and main branches with protectant or systemic fungicides can be effective. Recommended chemicals include copper oxychloride, mancozeb, propiconazole, or hexaconazole, applied according to label instructions. Frequency is typically every 2-4 weeks during the wet season.
# 15. `Prevention`: Preventive measures are more effective and economical than treatment. An integrated approach is essential.
# *   **Canopy Management:** This is the most critical preventive measure. Annually prune trees to create an open canopy structure that allows good air circulation and sunlight penetration. Remove vertical water sprouts, crossing branches, and dense foliage.
# *   **Sanitation:** Remove all pruned infected branches from the orchard and burn or bury them deeply to reduce the inoculum source.
# *   **Proper Spacing:** Adhere to recommended planting distances (e.g., 10m x 10m or wider) to prevent overcrowding.
# *   **Tool Sterilization:** Always disinfect pruning tools with a 10% bleach solution, 70% alcohol, or a commercial disinfectant when moving from one tree to another.
# *   **Prophylactic Application:** Before the onset of the rainy season, paint or spray the main trunk and primary branch forks with Bordeaux mixture or a copper-based fungicide as a protective barrier.
# *   **Regular Monitoring:** Scout the orchard frequently, especially during wet weather, to detect the early 'cobweb' stage of the disease for timely intervention.
# 16. `Locations`: Pink Disease is endemic and widespread in humid tropical climates where durian is cultivated.
# *   **Malaysia:** Prevalent in all major durian-growing states, including Pahang, Johor, Perak, and Sabah, due to high rainfall and humidity.
# *   **Thailand:** Common in the main production zones of the eastern (Chanthaburi, Rayong, Trat) and southern regions, which have a pronounced rainy season.
# *   **Indonesia:** Widely reported in durian cultivation areas on Sumatra, Java, and Kalimantan.
# *   **Vietnam:** A significant disease in the Mekong Delta and the Southeast region.
# *   **Philippines:** Reported as a major disease, particularly in Mindanao.
# *   **Other Regions:** Found in other durian-growing countries like Sri Lanka, India, and other parts of tropical Asia, Africa, and the Americas on various host plants.

# %%
from disease_schema import node_types, relation_types, allowed_relationships

NODE_TYPES = [node_type["label"] for node_type in node_types]
RELATION_TYPES = [relation_type["label"] for relation_type in relation_types]
ALLOWED_RELATIONSHIPS = allowed_relationships

# %%
NODE_TYPES
# Out:
# ['CROP',
#  'VARIETY',
#  'DISEASE',
#  'CROP_PART',
#  'SYMPTOM',
#  'PATHOGEN',
#  'CONDITION',
#  'SEASONALITY',
#  'LOCATION',
#  'TREATMENT',
#  'PREVENTION_METHOD',
#  'SPREAD_METHOD',
#  'RISK_FACTOR']

# %%
RELATION_TYPES
# Out:
# ['HAS_VARIETY',
#  'AFFECTED_BY',
#  'SUSCEPTIBLE_TO',
#  'HAS_CROP_PART',
#  'HAS_SYMPTOM',
#  'HAS_DISEASE',
#  'CAUSED_BY',
#  'PEAKS_DURING',
#  'MANAGED_BY',
#  'PREVENTED_BY',
#  'SPREADS_VIA',
#  'TRIGGERED_BY',
#  'OCCURS_IN']

# %%
ALLOWED_RELATIONSHIPS
# Out:
# [('CROP', 'HAS_VARIETY', 'VARIETY'),
#  ('CROP', 'AFFECTED_BY', 'DISEASE'),
#  ('VARIETY', 'SUSCEPTIBLE_TO', 'DISEASE'),
#  ('CROP', 'HAS_CROP_PART', 'CROP_PART'),
#  ('CROP_PART', 'HAS_SYMPTOM', 'SYMPTOM'),
#  ('CROP_PART', 'HAS_DISEASE', 'DISEASE'),
#  ('DISEASE', 'CAUSED_BY', 'PATHOGEN'),
#  ('DISEASE', 'CAUSED_BY', 'CONDITION'),
#  ('DISEASE', 'PEAKS_DURING', 'SEASONALITY'),
#  ('DISEASE', 'MANAGED_BY', 'TREATMENT'),
#  ('DISEASE', 'PREVENTED_BY', 'PREVENTION_METHOD'),
#  ('DISEASE', 'SPREADS_VIA', 'SPREAD_METHOD'),
#  ('DISEASE', 'TRIGGERED_BY', 'RISK_FACTOR'),
#  ('DISEASE', 'OCCURS_IN', 'LOCATION')]

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model_name=MODEL_NAME, temperature=0)
llm_transformer = LLMGraphTransformer(
    llm=llm,
    allowed_nodes=NODE_TYPES,
    allowed_relationships=ALLOWED_RELATIONSHIPS,
)

# %%
from langchain_core.documents import Document

documents = [Document(page_content=document) for document in documents]

graph_documents = await llm_transformer.aconvert_to_graph_documents(documents)

for graph_document in graph_documents:
    print(f"Nodes ({len(graph_document.nodes)}):{graph_document.nodes}")
    print(f"Relationships ({len(graph_document.relationships)}):{graph_document.relationships}")
# Out:
# Nodes (57):[Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), Node(id='Phomopsis Durionis', type='Pathogen', properties={}), Node(id='Diaporthe Sp.', type='Pathogen', properties={}), Node(id='Leaves', type='Crop_part', properties={}), Node(id='Twigs', type='Crop_part', properties={}), Node(id='Small Circular Water-Soaked Lesions', type='Symptom', properties={}), Node(id='Yellowish-Brown To Greyish-Brown Spots With Dark Brown Or Purplish Border And Yellow Halo', type='Symptom', properties={}), Node(id='Large Irregular Necrotic Patches', type='Symptom', properties={}), Node(id='Black Flask-Shaped Pycnidia', type='Symptom', properties={}), Node(id='Cankers On Twigs', type='Symptom', properties={}), Node(id='Twig Dieback', type='Symptom', properties={}), Node(id='Hot Humid Conditions', type='Condition', properties={}), Node(id='High Humidity', type='Condition', properties={}), Node(id='Prolonged Leaf Wetness', type='Condition', properties={}), Node(id='Wounds', type='Condition', properties={}), Node(id='Plant Stress', type='Condition', properties={}), Node(id='Rain Splash', type='Spread_method', properties={}), Node(id='Wind-Driven Rain', type='Spread_method', properties={}), Node(id='Contaminated Tools', type='Spread_method', properties={}), Node(id='Infected Planting Material', type='Spread_method', properties={}), Node(id='Rainy Season', type='Seasonality', properties={}), Node(id='Dense Planting', type='Risk_factor', properties={}), Node(id='Overhead Irrigation', type='Risk_factor', properties={}), Node(id='Poor Sanitation', type='Risk_factor', properties={}), Node(id='Unbalanced Fertilization', type='Risk_factor', properties={}), Node(id='Thick Unpruned Canopy', type='Risk_factor', properties={}), Node(id='Susceptible Growth Stages', type='Risk_factor', properties={}), Node(id='D24 (Sultan)', type='Variety', properties={}), Node(id='D99 (Kop Kecil)', type='Variety', properties={}), Node(id='Chanee (D123)', type='Variety', properties={}), Node(id='Monthong (D159)', type='Variety', properties={}), Node(id='Ri6', type='Variety', properties={}), Node(id='Musang King (D197)', type='Variety', properties={}), Node(id='Mancozeb', type='Treatment', properties={}), Node(id='Chlorothalonil', type='Treatment', properties={}), Node(id='Copper Hydroxide', type='Treatment', properties={}), Node(id='Copper Oxychloride', type='Treatment', properties={}), Node(id='Propiconazole', type='Treatment', properties={}), Node(id='Difenoconazole', type='Treatment', properties={}), Node(id='Tebuconazole', type='Treatment', properties={}), Node(id='Azoxystrobin', type='Treatment', properties={}), Node(id='Thiophanate-Methyl', type='Treatment', properties={}), Node(id='Trichoderma Spp.', type='Treatment', properties={}), Node(id='Bacillus Subtilis', type='Treatment', properties={}), Node(id='Canopy Management', type='Prevention_method', properties={}), Node(id='Orchard Sanitation', type='Prevention_method', properties={}), Node(id='Water Management', type='Prevention_method', properties={}), Node(id='Nutrient Management', type='Prevention_method', properties={}), Node(id='Planting Material', type='Prevention_method', properties={}), Node(id='Tool Sterilization', type='Prevention_method', properties={}), Node(id='Regular Monitoring', type='Prevention_method', properties={}), Node(id='Durian', type='Crop', properties={}), Node(id='Thailand', type='Location', properties={}), Node(id='Vietnam', type='Location', properties={}), Node(id='Malaysia', type='Location', properties={}), Node(id='Philippines', type='Location', properties={}), Node(id='Indonesia', type='Location', properties={})]
# Relationships (54):[Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), type='AFFECTED_BY', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Phomopsis Durionis', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Diaporthe Sp.', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Small Circular Water-Soaked Lesions', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Yellowish-Brown To Greyish-Brown Spots With Dark Brown Or Purplish Border And Yellow Halo', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Large Irregular Necrotic Patches', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Black Flask-Shaped Pycnidia', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Twigs', type='Crop_part', properties={}), target=Node(id='Cankers On Twigs', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Twigs', type='Crop_part', properties={}), target=Node(id='Twig Dieback', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Hot Humid Conditions', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='High Humidity', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Prolonged Leaf Wetness', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Wounds', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Plant Stress', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Rain Splash', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Wind-Driven Rain', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Contaminated Tools', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Infected Planting Material', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Rainy Season', type='Seasonality', properties={}), type='PEAKS_DURING', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Dense Planting', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Phomopsis Leaf Blight', type='Disease', properties={}), target=Node(id='Overhead Irrigation', type='Risk_factor', properties={}), type='TRIGGERE ...
# Nodes (57):[Node(id='Pink Disease', type='Disease', properties={}), Node(id='Bệnh Nấm Hồng', type='Disease', properties={}), Node(id='โรคราสีชมพู (Rok Ra Si Chomphu)', type='Disease', properties={}), Node(id='Erythricium Salmonicolor', type='Pathogen', properties={}), Node(id='Necator Salmonicolor', type='Pathogen', properties={}), Node(id='Corticium Salmonicolor', type='Pathogen', properties={}), Node(id='Branch Canker', type='Disease', properties={}), Node(id='Stem Canker', type='Disease', properties={}), Node(id='Cobweb Disease', type='Disease', properties={}), Node(id='Penyakit Kulapuk Merah Jambu', type='Disease', properties={}), Node(id='Cendawan Angin', type='Disease', properties={}), Node(id='Durian', type='Crop', properties={}), Node(id='Monthong (D159)', type='Variety', properties={}), Node(id='Musang King (D197)', type='Variety', properties={}), Node(id='Chanee (D123)', type='Variety', properties={}), Node(id='Ri6', type='Variety', properties={}), Node(id='D24 (Sultan)', type='Variety', properties={}), Node(id='Kanyao (D158)', type='Variety', properties={}), Node(id='Bark', type='Crop_part', properties={}), Node(id='Branches', type='Crop_part', properties={}), Node(id='Main Trunk', type='Crop_part', properties={}), Node(id='White Silky Mycelial Threads', type='Symptom', properties={}), Node(id='Orange-Red Pustules', type='Symptom', properties={}), Node(id='Salmon-Pink To Bright Orange-Pink Crust', type='Symptom', properties={}), Node(id='Bark Cracking And Splitting', type='Symptom', properties={}), Node(id='Gum Exudation', type='Symptom', properties={}), Node(id='Leaf Yellowing, Wilting, Drying, And Dying', type='Symptom', properties={}), Node(id='High Humidity', type='Condition', properties={}), Node(id='Prolonged Wetness', type='Condition', properties={}), Node(id='Poor Air Circulation', type='Condition', properties={}), Node(id='Airborne Spores', type='Spread_method', properties={}), Node(id='Rain Splash', type='Spread_method', properties={}), Node(id='Contaminated Tools', type='Spread_method', properties={}), Node(id='Monsoon Or Rainy Season', type='Seasonality', properties={}), Node(id='Pruning', type='Treatment', properties={}), Node(id='Scraping', type='Treatment', properties={}), Node(id='Bordeaux Mixture', type='Treatment', properties={}), Node(id='Copper Oxychloride', type='Treatment', properties={}), Node(id='Systemic Fungicides', type='Treatment', properties={}), Node(id='Calixin (Tridemorph)', type='Treatment', properties={}), Node(id='Foliar/Branch Sprays', type='Treatment', properties={}), Node(id='Canopy Management', type='Prevention_method', properties={}), Node(id='Sanitation', type='Prevention_method', properties={}), Node(id='Proper Spacing', type='Prevention_method', properties={}), Node(id='Tool Sterilization', type='Prevention_method', properties={}), Node(id='Prophylactic Application', type='Prevention_method', properties={}), Node(id='Regular Monitoring', type='Prevention_method', properties={}), Node(id='Malaysia', type='Location', properties={}), Node(id='Thailand', type='Location', properties={}), Node(id='Indonesia', type='Location', properties={}), Node(id='Vietnam', type='Location', properties={}), Node(id='Philippines', type='Location', properties={}), Node(id='Sri Lanka', type='Location', properties={}), Node(id='India', type='Location', properties={}), Node(id='Tropical Asia', type='Location', properties={}), Node(id='Africa', type='Location', properties={}), Node(id='Americas', type='Location', properties={})]
# Relationships (49):[Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Erythricium Salmonicolor', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Bark', type='Crop_part', properties={}), target=Node(id='White Silky Mycelial Threads', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Bark', type='Crop_part', properties={}), target=Node(id='Orange-Red Pustules', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Bark', type='Crop_part', properties={}), target=Node(id='Salmon-Pink To Bright Orange-Pink Crust', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Bark', type='Crop_part', properties={}), target=Node(id='Bark Cracking And Splitting', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Bark', type='Crop_part', properties={}), target=Node(id='Gum Exudation', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Branches', type='Crop_part', properties={}), target=Node(id='Leaf Yellowing, Wilting, Drying, And Dying', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='High Humidity', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Prolonged Wetness', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Poor Air Circulation', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Airborne Spores', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Rain Splash', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Contaminated Tools', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Monsoon Or Rainy Season', type='Seasonality', properties={}), type='PEAKS_DURING', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Pruning', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Scraping', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Bordeaux Mixture', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Copper Oxychloride', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Systemic Fungicides', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Calixin (Tridemorph)', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Foliar/Branch Sprays', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Pink Disease', type='Disease', properties={}), target=Node(id='Canopy Management', type='Prevention_method', prope ...
# Nodes (55):[Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), Node(id='Bệnh Cháy Lá Do Nấm Rhizoctonia', type='Disease', properties={}), Node(id='โรคใบติด', type='Disease', properties={}), Node(id='Rhizoctonia Solani J.G. Kühn', type='Pathogen', properties={}), Node(id='Web Blight', type='Disease', properties={}), Node(id='Target Leaf Spot', type='Disease', properties={}), Node(id='Leaf-Sticking Disease', type='Disease', properties={}), Node(id='Rhizoctonia Blight', type='Disease', properties={}), Node(id='Penyakit Hawar Daun', type='Disease', properties={}), Node(id='Durian', type='Crop', properties={}), Node(id='Leaves', type='Crop_part', properties={}), Node(id='Initial Lesions', type='Symptom', properties={}), Node(id='Lesion Development', type='Symptom', properties={}), Node(id='Mycelial Webbing', type='Symptom', properties={}), Node(id='Blight And Defoliation', type='Symptom', properties={}), Node(id='High Humidity', type='Condition', properties={}), Node(id='Prolonged Leaf Wetness', type='Condition', properties={}), Node(id='Warm Temperatures', type='Condition', properties={}), Node(id='Poor Air Circulation', type='Condition', properties={}), Node(id='Mechanical Transmission', type='Spread_method', properties={}), Node(id='Water-Assisted Transmission', type='Spread_method', properties={}), Node(id='Rain Splash', type='Spread_method', properties={}), Node(id='Human/Mechanical Transmission', type='Spread_method', properties={}), Node(id='Infected Planting Material', type='Spread_method', properties={}), Node(id='Monsoon Season', type='Seasonality', properties={}), Node(id='Rainy Season', type='Seasonality', properties={}), Node(id='Mancozeb', type='Treatment', properties={}), Node(id='Chlorothalonil', type='Treatment', properties={}), Node(id='Copper Hydroxide', type='Treatment', properties={}), Node(id='Bordeaux Mixture', type='Treatment', properties={}), Node(id='Validamycin', type='Treatment', properties={}), Node(id='Hexaconazole', type='Treatment', properties={}), Node(id='Propiconazole', type='Treatment', properties={}), Node(id='Pencycuron', type='Treatment', properties={}), Node(id='Trichoderma Spp.', type='Treatment', properties={}), Node(id='Bacillus Subtilis', type='Treatment', properties={}), Node(id='Pruning', type='Prevention_method', properties={}), Node(id='Spacing', type='Prevention_method', properties={}), Node(id='Drip Or Micro-Jet Irrigation', type='Prevention_method', properties={}), Node(id='Good Soil Drainage', type='Prevention_method', properties={}), Node(id='Mulching', type='Prevention_method', properties={}), Node(id='Weed Control', type='Prevention_method', properties={}), Node(id='Tool Sterilization', type='Prevention_method', properties={}), Node(id='Debris Removal', type='Prevention_method', properties={}), Node(id='Nursery Management', type='Prevention_method', properties={}), Node(id='Monthong (D159)', type='Variety', properties={}), Node(id='Musang King (D197)', type='Variety', properties={}), Node(id='Ri6 (Vietnam)', type='Variety', properties={}), Node(id='Chanee (D123)', type='Variety', properties={}), Node(id='Puyat (Philippines)', type='Variety', properties={}), Node(id='Thailand', type='Location', properties={}), Node(id='Vietnam', type='Location', properties={}), Node(id='Malaysia', type='Location', properties={}), Node(id='Indonesia', type='Location', properties={}), Node(id='Philippines', type='Location', properties={})]
# Relationships (52):[Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), type='AFFECTED_BY', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Rhizoctonia Solani J.G. Kühn', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='High Humidity', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Prolonged Leaf Wetness', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Warm Temperatures', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Poor Air Circulation', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Leaves', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Initial Lesions', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Lesion Development', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Mycelial Webbing', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Blight And Defoliation', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Mechanical Transmission', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Water-Assisted Transmission', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Rain Splash', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Human/Mechanical Transmission', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Infected Planting Material', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Monsoon Season', type='Seasonality', properties={}), type='PEAKS_DURING', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Rainy Season', type='Seasonality', properties={}), type='PEAKS_DURING', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Mancozeb', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Chlorothalonil', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Rhizoctonia Leaf Blight', type='Disease', properties={}), target=Node(id='Copper Hydroxide', type='Treatment', properties={}), type='MANAGED_BY', properties={}),  ...
# Nodes (73):[Node(id='Phytophthora Fruit Rot Of Durian', type='Disease', properties={}), Node(id='Durian', type='Crop', properties={}), Node(id='Phytophthora Palmivora', type='Pathogen', properties={}), Node(id='P. Nicotianae', type='Pathogen', properties={}), Node(id='P. Katsurae', type='Pathogen', properties={}), Node(id='Fruit', type='Crop_part', properties={}), Node(id='Leaves', type='Crop_part', properties={}), Node(id='Stems/Trunk', type='Crop_part', properties={}), Node(id='Roots', type='Crop_part', properties={}), Node(id='Small Circular Water-Soaked Dark Olive-Green To Brown Spots', type='Symptom', properties={}), Node(id='Dark Brown To Black Lesions', type='Symptom', properties={}), Node(id='White Cottony Mycelial Growth', type='Symptom', properties={}), Node(id='Brownish Watery Discolored Pulp', type='Symptom', properties={}), Node(id='Dark Brown To Black Discoloration Of Husk Tissue', type='Symptom', properties={}), Node(id='Large Irregular Necrotic Brown Patches', type='Symptom', properties={}), Node(id='Reddish-Brown Or Dark Amber-Colored Sap Oozing', type='Symptom', properties={}), Node(id='Feeder Root Decay', type='Symptom', properties={}), Node(id='Yellowing Of Leaves (Chlorosis)', type='Symptom', properties={}), Node(id='Wilting', type='Symptom', properties={}), Node(id='Premature Fruit Drop', type='Symptom', properties={}), Node(id='Rotten Foul-Smelling Fruit Mass', type='Symptom', properties={}), Node(id='High Humidity', type='Condition', properties={}), Node(id='High Rainfall', type='Condition', properties={}), Node(id='Presence Of Free Water On Fruit Surface', type='Condition', properties={}), Node(id='Prolonged Rainy Seasons', type='Condition', properties={}), Node(id='High Relative Humidity >90%', type='Condition', properties={}), Node(id='Frequent Mist Or Dew', type='Condition', properties={}), Node(id='Warm Temperatures 26-32°C', type='Condition', properties={}), Node(id='Poorly Drained Or Waterlogged Soils', type='Condition', properties={}), Node(id='Dense Canopies From Inadequate Pruning', type='Condition', properties={}), Node(id='Fruit Hanging Low To The Ground', type='Condition', properties={}), Node(id='Infected Plant Debris On Orchard Floor', type='Condition', properties={}), Node(id='Active Cankers On Trunk Or Branches', type='Condition', properties={}), Node(id='Thick-Walled Resting Spores (Chlamydospores)', type='Pathogen', properties={}), Node(id='Rain Splash', type='Spread_method', properties={}), Node(id='Wind-Driven Rain', type='Spread_method', properties={}), Node(id='Surface Water Flow', type='Spread_method', properties={}), Node(id='Zoospores', type='Pathogen', properties={}), Node(id='Human And Equipment', type='Spread_method', properties={}), Node(id='Monsoon Season', type='Seasonality', properties={}), Node(id='Low-Lying Poorly Drained Areas', type='Risk_factor', properties={}), Node(id='Dense Unpruned Canopies', type='Risk_factor', properties={}), Node(id='Failure To Remove And Destroy Fallen Infected Fruit And Pruned Debris', type='Risk_factor', properties={}), Node(id='Fruits On Lower Branches Less Than 1.5 Meters From Ground', type='Risk_factor', properties={}), Node(id='Heavy Clay Soils', type='Risk_factor', properties={}), Node(id='Older Trees With Accumulated Inoculum', type='Risk_factor', properties={}), Node(id='Stressed Or Wounded Trees', type='Risk_factor', properties={}), Node(id='Monthong (D159)', type='Variety', properties={}), Node(id='Chanee (D123)', type='Variety', properties={}), Node(id='Kanyao (D158)', type='Variety', properties={}), Node(id='Musang King (D197, Raja Kunyit)', type='Variety', properties={}), Node(id='Black Thorn (D200)', type='Variety', properties={}), Node(id='Ri6', type='Variety', properties={}), Node(id='Gumpun', type='Variety', properties={}), Node(id='Rainy Season', type='Seasonality', properties={}), Node(id='Phosphorous Acid (Phosphonates)', type='Treatment', properties={}), Node(id='Metalaxyl-M (Mefenoxam)', type='Treatment', properties={} ...
# Relationships (76):[Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Phytophthora Fruit Rot Of Durian', type='Disease', properties={}), type='AFFECTED_BY', properties={}), Relationship(source=Node(id='Phytophthora Fruit Rot Of Durian', type='Disease', properties={}), target=Node(id='Phytophthora Palmivora', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phytophthora Fruit Rot Of Durian', type='Disease', properties={}), target=Node(id='P. Nicotianae', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phytophthora Fruit Rot Of Durian', type='Disease', properties={}), target=Node(id='P. Katsurae', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Fruit', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Leaves', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Stems/Trunk', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Roots', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='Small Circular Water-Soaked Dark Olive-Green To Brown Spots', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='Dark Brown To Black Lesions', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='White Cottony Mycelial Growth', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='Brownish Watery Discolored Pulp', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='Dark Brown To Black Discoloration Of Husk Tissue', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Large Irregular Necrotic Brown Patches', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Stems/Trunk', type='Crop_part', properties={}), target=Node(id='Reddish-Brown Or Dark Amber-Colored Sap Oozing', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Roots', type='Crop_part', properties={}), target=Node(id='Feeder Root Decay', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Roots', type='Crop_part', properties={}), target=Node(id='Yellowing Of Leaves (Chlorosis)', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Roots', type='Crop_part', properties={}), target=Node(id='Wilting', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='Premature Fruit Drop', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='Rotten Foul-Smelling Fruit Mass', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Phytophthora Fruit Rot Of Durian', type='Disease', properties={}), target=Node(id='High Humidity', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phytophthora Fruit Rot Of Duria ...
# Nodes (100):[Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), Node(id='Durian', type='Crop', properties={}), Node(id='Musang King', type='Variety', properties={}), Node(id='D197', type='Variety', properties={}), Node(id='Raja Kunyit', type='Variety', properties={}), Node(id='D24', type='Variety', properties={}), Node(id='Sultan', type='Variety', properties={}), Node(id='D168', type='Variety', properties={}), Node(id='Hajah Hasmah', type='Variety', properties={}), Node(id='Ioi', type='Variety', properties={}), Node(id='Monthong', type='Variety', properties={}), Node(id='D159', type='Variety', properties={}), Node(id='Golden Pillow', type='Variety', properties={}), Node(id='Chanee', type='Variety', properties={}), Node(id='D123', type='Variety', properties={}), Node(id='Ri6', type='Variety', properties={}), Node(id='Vietnam', type='Location', properties={}), Node(id='Fusarium Oxysporum F. Sp. Durionis', type='Pathogen', properties={}), Node(id='Fusarium Solani', type='Pathogen', properties={}), Node(id='Fusarium Proliferatum', type='Pathogen', properties={}), Node(id='Fusarium Incarnatum-Equiseti Species Complex', type='Pathogen', properties={}), Node(id='Soil', type='Condition', properties={}), Node(id='Waterlogged Soil', type='Condition', properties={}), Node(id='Acidic Soil', type='Condition', properties={}), Node(id='Excessive Nitrogen Fertilizers', type='Risk_factor', properties={}), Node(id='Tree Stress', type='Risk_factor', properties={}), Node(id='Soil And Plant Debris', type='Spread_method', properties={}), Node(id='Infected Planting Material', type='Spread_method', properties={}), Node(id='Water', type='Spread_method', properties={}), Node(id='Pruning Tools', type='Spread_method', properties={}), Node(id='Prolonged Rainy Seasons', type='Risk_factor', properties={}), Node(id='High Humidity', type='Risk_factor', properties={}), Node(id='Warm Temperatures', type='Risk_factor', properties={}), Node(id='Heavy Clay Soils', type='Condition', properties={}), Node(id='Dense Planting', type='Risk_factor', properties={}), Node(id='Wounding Of Roots', type='Risk_factor', properties={}), Node(id='Lack Of Orchard Sanitation', type='Risk_factor', properties={}), Node(id='Failure To Disinfect Tools', type='Risk_factor', properties={}), Node(id='Leaves', type='Crop_part', properties={}), Node(id='Stem', type='Crop_part', properties={}), Node(id='Trunk', type='Crop_part', properties={}), Node(id='Branches', type='Crop_part', properties={}), Node(id='Roots', type='Crop_part', properties={}), Node(id='Fruit', type='Crop_part', properties={}), Node(id='Unilateral Yellowing', type='Symptom', properties={}), Node(id='Wilting', type='Symptom', properties={}), Node(id='Drooping', type='Symptom', properties={}), Node(id='Brown Leaves', type='Symptom', properties={}), Node(id='Premature Defoliation', type='Symptom', properties={}), Node(id='Stunted Young Leaves', type='Symptom', properties={}), Node(id='Dark Brown To Black Vascular Discoloration', type='Symptom', properties={}), Node(id='Dieback Of Twigs And Branches', type='Symptom', properties={}), Node(id='Longitudinal Cracking Of Bark', type='Symptom', properties={}), Node(id='Reddish-Brown Gum Oozing', type='Symptom', properties={}), Node(id='Root Rot', type='Symptom', properties={}), Node(id='Dark Brown To Black Roots', type='Symptom', properties={}), Node(id='Dark Sunken Water-Soaked Lesions On Fruit Husk', type='Symptom', properties={}), Node(id='White Or Pinkish Fungal Mycelium On Fruit', type='Symptom', properties={}), Node(id='Fruit Pulp Discoloration', type='Symptom', properties={}), Node(id='Watery Fruit Texture', type='Symptom', properties={}), Node(id='Foul Odor Of Fruit', type='Symptom', properties={}), Node(id='Trunk Injection Fungicides', type='Treatment', properties={}), Node(id='Soil Drenching Fungicides', type='Treatment', properties={}), Node(id='Hymexazol', type='Treatment', properties={}), Node(id='Fosetyl-Aluminium', type='Treatment', properties={}), No ...
# Relationships (95):[Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), type='AFFECTED_BY', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Leaves', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Stem', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Trunk', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Branches', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Roots', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Fruit', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Fusarium Oxysporum F. Sp. Durionis', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Fusarium Solani', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Fusarium Proliferatum', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Fusarium Incarnatum-Equiseti Species Complex', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Soil', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Waterlogged Soil', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Acidic Soil', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Excessive Nitrogen Fertilizers', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Tree Stress', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Soil And Plant Debris', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Infected Planting Material', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Water', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Pruning Tools', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', properties={}), target=Node(id='Prolonged Rainy Seasons', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Fusarium Wilt Of Durian', type='Disease', proper ...
# Nodes (60):[Node(id='Powdery Mildew', type='Disease', properties={}), Node(id='Bệnh Phấn Trắng', type='Disease', properties={}), Node(id='โรคราแป้ง (Rok Ra Paeng)', type='Disease', properties={}), Node(id='Oidium Sp.', type='Pathogen', properties={}), Node(id='White Mold', type='Disease', properties={}), Node(id='Fungal Dust', type='Disease', properties={}), Node(id='Nấm Phấn Trắng', type='Disease', properties={}), Node(id='Durian', type='Crop', properties={}), Node(id='Leaves', type='Crop_part', properties={}), Node(id='Flowers', type='Crop_part', properties={}), Node(id='Young Fruits', type='Crop_part', properties={}), Node(id='Shoots', type='Crop_part', properties={}), Node(id='White Powdery Patches', type='Symptom', properties={}), Node(id='Leaf Curling', type='Symptom', properties={}), Node(id='Leaf Yellowing', type='Symptom', properties={}), Node(id='Leaf Brittleness', type='Symptom', properties={}), Node(id='Premature Leaf Drop', type='Symptom', properties={}), Node(id='White Mycelial Mat On Flowers', type='Symptom', properties={}), Node(id='Flower Drop', type='Symptom', properties={}), Node(id='White Powdery Spots On Young Fruits', type='Symptom', properties={}), Node(id='Fruit Discoloration', type='Symptom', properties={}), Node(id='Rough Corky Or Scabby Fruit Texture', type='Symptom', properties={}), Node(id='Stunted Young Fruits', type='Symptom', properties={}), Node(id='White Fungal Growth On Shoots', type='Symptom', properties={}), Node(id='Stunted Shoot Development', type='Symptom', properties={}), Node(id='Shoot Dieback', type='Symptom', properties={}), Node(id='High Humidity', type='Condition', properties={}), Node(id='Dry Weather', type='Condition', properties={}), Node(id='Airborne Conidia', type='Spread_method', properties={}), Node(id='High Relative Humidity (80-95%)', type='Risk_factor', properties={}), Node(id='Dry Season', type='Seasonality', properties={}), Node(id='Cool Humid Nights And Warm Dry Days', type='Risk_factor', properties={}), Node(id='Dense Canopy', type='Risk_factor', properties={}), Node(id='Close Planting', type='Risk_factor', properties={}), Node(id='Excessive Nitrogen', type='Risk_factor', properties={}), Node(id='Young Developing Tissues', type='Risk_factor', properties={}), Node(id='Monthong (D159)', type='Variety', properties={}), Node(id='Chanee (D123)', type='Variety', properties={}), Node(id='Musang King (D197)', type='Variety', properties={}), Node(id='Ri6', type='Variety', properties={}), Node(id='Kanyao (D158)', type='Variety', properties={}), Node(id='Dry Season And Transitional Periods With Dew Formation', type='Seasonality', properties={}), Node(id='Sulfur-Based Fungicides', type='Treatment', properties={}), Node(id='Triazoles (Dmi Fungicides)', type='Treatment', properties={}), Node(id='Strobilurins (Qoi Fungicides)', type='Treatment', properties={}), Node(id='Potassium Bicarbonate', type='Treatment', properties={}), Node(id='Horticultural Oils', type='Treatment', properties={}), Node(id='Bacillus Subtilis Strains (E.G., Qst 713)', type='Treatment', properties={}), Node(id='Ampelomyces Quisqualis', type='Treatment', properties={}), Node(id='Canopy Management', type='Prevention_method', properties={}), Node(id='Sanitation', type='Prevention_method', properties={}), Node(id='Water Management', type='Prevention_method', properties={}), Node(id='Nutrition Management', type='Prevention_method', properties={}), Node(id='Monitoring', type='Prevention_method', properties={}), Node(id='Prophylactic Spraying', type='Prevention_method', properties={}), Node(id='Thailand', type='Location', properties={}), Node(id='Vietnam', type='Location', properties={}), Node(id='Malaysia', type='Location', properties={}), Node(id='Philippines', type='Location', properties={}), Node(id='Indonesia', type='Location', properties={})]
# Relationships (58):[Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Monthong (D159)', type='Variety', properties={}), type='HAS_VARIETY', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Chanee (D123)', type='Variety', properties={}), type='HAS_VARIETY', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Musang King (D197)', type='Variety', properties={}), type='HAS_VARIETY', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Ri6', type='Variety', properties={}), type='HAS_VARIETY', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Kanyao (D158)', type='Variety', properties={}), type='HAS_VARIETY', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Leaves', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Flowers', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Young Fruits', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Shoots', type='Crop_part', properties={}), type='HAS_CROP_PART', properties={}), Relationship(source=Node(id='Powdery Mildew', type='Disease', properties={}), target=Node(id='Oidium Sp.', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Powdery Mildew', type='Disease', properties={}), target=Node(id='High Humidity', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Powdery Mildew', type='Disease', properties={}), target=Node(id='Dry Weather', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='White Powdery Patches', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Leaf Curling', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Leaf Yellowing', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Leaf Brittleness', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Premature Leaf Drop', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Flowers', type='Crop_part', properties={}), target=Node(id='White Mycelial Mat On Flowers', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Flowers', type='Crop_part', properties={}), target=Node(id='Flower Drop', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Young Fruits', type='Crop_part', properties={}), target=Node(id='White Powdery Spots On Young Fruits', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Young Fruits', type='Crop_part', properties={}), target=Node(id='Fruit Discoloration', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Young Fruits', type='Crop_part', properties={}), target=Node(id='Rough Corky Or Scabby Fruit Texture', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Young Fruits', type='Crop_part', properties={}), target=Node(id='Stunted Young Fruits', type='Symptom', pro ...
# ...
# Nodes (78):[Node(id='Phytophthora Patch Canker', type='Disease', properties={}), Node(id='Bệnh Nứt Thân Xì Mủ', type='Disease', properties={}), Node(id='โรคเปลือกแตกยางไหล', type='Disease', properties={}), Node(id='โรครากเน่าและโคนเน่า', type='Disease', properties={}), Node(id='Phytophthora Palmivora', type='Pathogen', properties={}), Node(id='Phytophthora Nicotianae', type='Pathogen', properties={}), Node(id='Phytophthora Heveae', type='Pathogen', properties={}), Node(id='Phytophthora Citrophthora', type='Pathogen', properties={}), Node(id='Gummosis', type='Disease', properties={}), Node(id='Stem Canker', type='Disease', properties={}), Node(id='Trunk Canker', type='Disease', properties={}), Node(id='Bark Rot', type='Disease', properties={}), Node(id='Stem Rot', type='Disease', properties={}), Node(id='Foot Rot', type='Disease', properties={}), Node(id='Bleeding Canker', type='Disease', properties={}), Node(id='Kanker Batang', type='Disease', properties={}), Node(id='Bệnh Thối Gốc Chảy Nhựa', type='Disease', properties={}), Node(id='Durian', type='Crop', properties={}), Node(id='Trunk', type='Crop_part', properties={}), Node(id='Trunk Collar', type='Crop_part', properties={}), Node(id='Main Branches', type='Crop_part', properties={}), Node(id='Roots', type='Crop_part', properties={}), Node(id='Foliage', type='Crop_part', properties={}), Node(id='Fruit', type='Crop_part', properties={}), Node(id='Dark Water-Soaked Lesions', type='Symptom', properties={}), Node(id='Reddish-Brown To Almost Black Viscous Sap', type='Symptom', properties={}), Node(id='Discolored Necrotic Inner Bark And Cambium', type='Symptom', properties={}), Node(id='Discolored Wood With Fermented Odor', type='Symptom', properties={}), Node(id='Dark Brown To Black Soft Rotted Roots', type='Symptom', properties={}), Node(id='Yellowing Leaves (Chlorosis)', type='Symptom', properties={}), Node(id='Wilting', type='Symptom', properties={}), Node(id='Smaller Leaf Size', type='Symptom', properties={}), Node(id='Premature Leaf Fall', type='Symptom', properties={}), Node(id='Dieback Of Terminal Shoots And Branches', type='Symptom', properties={}), Node(id='Thin And Unthrifty Canopy', type='Symptom', properties={}), Node(id='Small Water-Soaked Brownish Spots On Fruit', type='Symptom', properties={}), Node(id='White Mycelial Growth On Fruit Lesion', type='Symptom', properties={}), Node(id='Oomycete (Water Mold)', type='Pathogen', properties={}), Node(id='High Soil Moisture', type='Condition', properties={}), Node(id='Wounds', type='Condition', properties={}), Node(id='High Humidity And Trunk Wetness', type='Condition', properties={}), Node(id='Water', type='Spread_method', properties={}), Node(id='Infected Soil And Debris', type='Spread_method', properties={}), Node(id='Infected Planting Material', type='Spread_method', properties={}), Node(id='Contaminated Tools', type='Spread_method', properties={}), Node(id='High Rainfall', type='Risk_factor', properties={}), Node(id='High Relative Humidity', type='Risk_factor', properties={}), Node(id='Poorly Drained Heavy Clay Or Compacted Soils', type='Risk_factor', properties={}), Node(id='Low-Lying Or Flat Areas', type='Risk_factor', properties={}), Node(id='Close Planting Density', type='Risk_factor', properties={}), Node(id='Overhead Or Sprinkler Irrigation', type='Risk_factor', properties={}), Node(id='Planting Seedlings Too Deep', type='Risk_factor', properties={}), Node(id='Thick Mulch Against Trunk', type='Risk_factor', properties={}), Node(id='Excessive Nitrogen Fertilizer', type='Risk_factor', properties={}), Node(id='Mechanical Weed Control Or Herbicide Causing Wounds', type='Risk_factor', properties={}), Node(id='Monthong', type='Variety', properties={}), Node(id='Chanee', type='Variety', properties={}), Node(id='D24', type='Variety', properties={}), Node(id='Kanyao', type='Variety', properties={}), Node(id='Ri6', type='Variety', properties={}), Node(id='Puyat', type='Variety', properties={}), Node(id='Durio Lowianus', ty ...
# Relationships (57):[Relationship(source=Node(id='Durian', type='Crop', properties={}), target=Node(id='Phytophthora Patch Canker', type='Disease', properties={}), type='AFFECTED_BY', properties={}), Relationship(source=Node(id='Phytophthora Patch Canker', type='Disease', properties={}), target=Node(id='Phytophthora Palmivora', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phytophthora Patch Canker', type='Disease', properties={}), target=Node(id='Phytophthora Nicotianae', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phytophthora Patch Canker', type='Disease', properties={}), target=Node(id='Phytophthora Heveae', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phytophthora Patch Canker', type='Disease', properties={}), target=Node(id='Phytophthora Citrophthora', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Trunk', type='Crop_part', properties={}), target=Node(id='Dark Water-Soaked Lesions', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Trunk', type='Crop_part', properties={}), target=Node(id='Reddish-Brown To Almost Black Viscous Sap', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Trunk', type='Crop_part', properties={}), target=Node(id='Discolored Necrotic Inner Bark And Cambium', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Trunk', type='Crop_part', properties={}), target=Node(id='Discolored Wood With Fermented Odor', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Roots', type='Crop_part', properties={}), target=Node(id='Dark Brown To Black Soft Rotted Roots', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Foliage', type='Crop_part', properties={}), target=Node(id='Yellowing Leaves (Chlorosis)', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Foliage', type='Crop_part', properties={}), target=Node(id='Wilting', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Foliage', type='Crop_part', properties={}), target=Node(id='Smaller Leaf Size', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Foliage', type='Crop_part', properties={}), target=Node(id='Premature Leaf Fall', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Foliage', type='Crop_part', properties={}), target=Node(id='Dieback Of Terminal Shoots And Branches', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Foliage', type='Crop_part', properties={}), target=Node(id='Thin And Unthrifty Canopy', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='Small Water-Soaked Brownish Spots On Fruit', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='White Mycelial Growth On Fruit Lesion', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Phytophthora Patch Canker', type='Disease', properties={}), target=Node(id='Oomycete (Water Mold)', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phytophthora Patch Canker', type='Disease', properties={}), target=Node(id='High Soil Moisture', type='Condition', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Phytophthora Patch Canker', type='Disease', properties={}), target=Node(id='Wounds', type='Condition', properties={}), type='CAUSED_B ...
# Nodes (40):[Node(id='Algal Leaf Spot', type='Disease', properties={}), Node(id='Cephaleuros Virescens', type='Pathogen', properties={}), Node(id='Leaves', type='Crop_part', properties={}), Node(id='Stems & Twigs', type='Crop_part', properties={}), Node(id='Fruit', type='Crop_part', properties={}), Node(id='Raised Velvety Spots', type='Symptom', properties={}), Node(id='Premature Defoliation', type='Symptom', properties={}), Node(id='Twig Dieback', type='Symptom', properties={}), Node(id='Reduced Photosynthetic Area', type='Symptom', properties={}), Node(id='High Relative Humidity', type='Risk_factor', properties={}), Node(id='Frequent And Prolonged Rainfall', type='Risk_factor', properties={}), Node(id='Poor Air Circulation', type='Risk_factor', properties={}), Node(id='Low Light Intensity', type='Risk_factor', properties={}), Node(id='Continuous Film Of Moisture', type='Risk_factor', properties={}), Node(id='Poor Plant Health And Vigor', type='Risk_factor', properties={}), Node(id='Water', type='Spread_method', properties={}), Node(id='Wind', type='Spread_method', properties={}), Node(id='Rain Splash', type='Spread_method', properties={}), Node(id='Copper Hydroxide', type='Treatment', properties={}), Node(id='Copper Oxychloride', type='Treatment', properties={}), Node(id='Bordeaux Mixture', type='Treatment', properties={}), Node(id='Lime Sulfur', type='Treatment', properties={}), Node(id='Pruning', type='Prevention_method', properties={}), Node(id='Sanitation', type='Prevention_method', properties={}), Node(id='Canopy Management', type='Prevention_method', properties={}), Node(id='Water & Soil Management', type='Prevention_method', properties={}), Node(id='Balanced Nutrition', type='Prevention_method', properties={}), Node(id='Thailand', type='Location', properties={}), Node(id='Vietnam', type='Location', properties={}), Node(id='Malaysia', type='Location', properties={}), Node(id='Indonesia', type='Location', properties={}), Node(id='Philippines', type='Location', properties={}), Node(id='Monthong (D159)', type='Variety', properties={}), Node(id='Musang King (D197)', type='Variety', properties={}), Node(id='Ri6', type='Variety', properties={}), Node(id='Chanee (D123)', type='Variety', properties={}), Node(id='D24', type='Variety', properties={}), Node(id='Black Thorn (D200)', type='Variety', properties={}), Node(id='Rainy Season', type='Seasonality', properties={}), Node(id='Monsoon Period', type='Seasonality', properties={})]
# Relationships (38):[Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Cephaleuros Virescens', type='Pathogen', properties={}), type='CAUSED_BY', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Raised Velvety Spots', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Reduced Photosynthetic Area', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Leaves', type='Crop_part', properties={}), target=Node(id='Premature Defoliation', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Stems & Twigs', type='Crop_part', properties={}), target=Node(id='Raised Velvety Spots', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Stems & Twigs', type='Crop_part', properties={}), target=Node(id='Twig Dieback', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Fruit', type='Crop_part', properties={}), target=Node(id='Raised Velvety Spots', type='Symptom', properties={}), type='HAS_SYMPTOM', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='High Relative Humidity', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Frequent And Prolonged Rainfall', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Poor Air Circulation', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Low Light Intensity', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Continuous Film Of Moisture', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Poor Plant Health And Vigor', type='Risk_factor', properties={}), type='TRIGGERED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Water', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Wind', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Rain Splash', type='Spread_method', properties={}), type='SPREADS_VIA', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Copper Hydroxide', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Copper Oxychloride', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Bordeaux Mixture', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Lime Sulfur', type='Treatment', properties={}), type='MANAGED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target=Node(id='Pruning', type='Prevention_method', properties={}), type='PREVENTED_BY', properties={}), Relationship(source=Node(id='Algal Leaf Spot', type='Disease', properties={}), target= ...

# %%
DELETE_EXISTING_DATA = True

if DELETE_EXISTING_DATA:
    graph.query("MATCH (n) DETACH DELETE n")

graph.add_graph_documents(graph_documents)

# %% [markdown]
# ## Querying

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv("/Users/mac/Documents/PHUNGPX/knowledge_graph_searching/.env")

if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

MODEL_NAME = "gpt-4.1-mini"

if "NEO4J_URI" not in os.environ:
    os.environ["NEO4J_URI"] = getpass.getpass("Enter your Neo4j URI: ")

if "NEO4J_USERNAME" not in os.environ:
    os.environ["NEO4J_USERNAME"] = getpass.getpass("Enter your Neo4j username: ")

if "NEO4J_PASSWORD" not in os.environ:
    os.environ["NEO4J_PASSWORD"] = getpass.getpass("Enter your Neo4j password: ")

# %%
import pandas as pd
from langchain_neo4j import Neo4jGraph

graph = Neo4jGraph(
    url=os.getenv("NEO4J_URI"),
    username=os.getenv("NEO4J_USERNAME"),
    password=os.getenv("NEO4J_PASSWORD"),
)

# %%
graph.refresh_schema()
print(graph.schema)
# Out:
# Node properties:
# Disease {id: STRING}
# Crop {id: STRING}
# Pathogen {id: STRING}
# Symptom {id: STRING}
# Variety {id: STRING}
# Seasonality {id: STRING}
# Location {id: STRING}
# Treatment {id: STRING}
# Crop_part {id: STRING}
# Condition {id: STRING}
# Spread_method {id: STRING}
# Risk_factor {id: STRING}
# Prevention_method {id: STRING}
# Relationship properties:
#
# The relationships:
# (:Disease)-[:MANAGED_BY]->(:Treatment)
# (:Disease)-[:CAUSED_BY]->(:Condition)
# (:Disease)-[:CAUSED_BY]->(:Pathogen)
# (:Disease)-[:TRIGGERED_BY]->(:Risk_factor)
# (:Disease)-[:SPREADS_VIA]->(:Spread_method)
# (:Disease)-[:PEAKS_DURING]->(:Seasonality)
# (:Disease)-[:OCCURS_IN]->(:Location)
# (:Disease)-[:PREVENTED_BY]->(:Prevention_method)
# (:Crop)-[:AFFECTED_BY]->(:Disease)
# (:Crop)-[:HAS_CROP_PART]->(:Crop_part)
# (:Crop)-[:HAS_VARIETY]->(:Variety)
# (:Variety)-[:SUSCEPTIBLE_TO]->(:Disease)
# (:Crop_part)-[:HAS_SYMPTOM]->(:Symptom)

# %%
enhanced_graph = Neo4jGraph(enhanced_schema=True)
print(enhanced_graph.schema)
# Out:
# Node properties:
# - **Disease**
#   - `id`: STRING Example: "Phomopsis Leaf Blight"
# - **Crop**
#   - `id`: STRING Available options: ['Durian']
# - **Pathogen**
#   - `id`: STRING Example: "Phomopsis Durionis"
# - **Symptom**
#   - `id`: STRING Example: "Small Circular Water-Soaked Lesions"
# - **Variety**
#   - `id`: STRING Example: "D24 (Sultan)"
# - **Seasonality**
#   - `id`: STRING Available options: ['Rainy Season', 'Monsoon Or Rainy Season', 'Monsoon Season', 'Dry Season', 'Dry Season And Transitional Periods With Dew Forma', 'Rainy Season May To November', 'Rainy/Monsoon Season', 'May To October In Thailand And Vietnam', 'Late-Year Monsoons In Malaysia', 'Monsoon Period']
# - **Location**
#   - `id`: STRING Example: "Thailand"
# - **Treatment**
#   - `id`: STRING Example: "Mancozeb"
# - **Crop_part**
#   - `id`: STRING Example: "Leaves"
# - **Condition**
#   - `id`: STRING Example: "Hot Humid Conditions"
# - **Spread_method**
#   - `id`: STRING Example: "Rain Splash"
# - **Risk_factor**
#   - `id`: STRING Example: "Dense Planting"
# - **Prevention_method**
#   - `id`: STRING Example: "Canopy Management"
# Relationship properties:
#
# The relationships:
# (:Disease)-[:MANAGED_BY]->(:Treatment)
# (:Disease)-[:CAUSED_BY]->(:Condition)
# (:Disease)-[:CAUSED_BY]->(:Pathogen)
# (:Disease)-[:TRIGGERED_BY]->(:Risk_factor)
# (:Disease)-[:SPREADS_VIA]->(:Spread_method)
# (:Disease)-[:PEAKS_DURING]->(:Seasonality)
# (:Disease)-[:OCCURS_IN]->(:Location)
# (:Disease)-[:PREVENTED_BY]->(:Prevention_method)
# (:Crop)-[:AFFECTED_BY]->(:Disease)
# (:Crop)-[:HAS_CROP_PART]->(:Crop_part)
# (:Crop)-[:HAS_VARIETY]->(:Variety)
# (:Variety)-[:SUSCEPTIBLE_TO]->(:Disease)
# (:Crop_part)-[:HAS_SYMPTOM]->(:Symptom)

# %%
from langchain_neo4j import GraphCypherQAChain
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o", temperature=0)
chain = GraphCypherQAChain.from_llm(
    graph=enhanced_graph,
    llm=llm,
    verbose=True,
    allow_dangerous_requests=True,
)

# %%
response = chain.invoke({"query": "Bệnh nào ảnh hưởng tới nhiều giống cây sầu riêng nhất?"})
response
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (c:Crop {id: 'Durian'})-[:HAS_VARIETY]->(v:Variety)-[:SUSCEPTIBLE_TO]->(d:Disease)
# RETURN d.id AS Disease, COUNT(v) AS VarietyCount
# ORDER BY VarietyCount DESC
# LIMIT 1
#
# Full Context:
# [{'Disease': 'Fusarium Wilt Of Durian', 'VarietyCount': 14}]
#
# > Finished chain.
# {'query': 'Bệnh nào ảnh hưởng tới nhiều giống cây sầu riêng nhất?',
#  'result': 'Bệnh Fusarium Wilt Of Durian ảnh hưởng tới nhiều giống cây sầu riêng nhất với 14 giống.'}

# %%
response = chain.invoke({"query": "Mùa nào xuất hiện nhiều sâu bệnh nhất?"})
response
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (d:Disease)-[:PEAKS_DURING]->(s:Seasonality)
# RETURN s.id, COUNT(d) AS disease_count
# ORDER BY disease_count DESC
# LIMIT 1
#
# Full Context:
# [{'s.id': 'Rainy Season', 'disease_count': 5}]
#
# > Finished chain.
# {'query': 'Mùa nào xuất hiện nhiều sâu bệnh nhất?',
#  'result': 'Mùa mưa xuất hiện nhiều sâu bệnh nhất với 5 loại bệnh.'}

# %%
response = chain.invoke({"query": "Bệnh nào xuất hiện của nhiều hơn 2 mùa trong năm và đó là những mùa nào?"})
response
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (d:Disease)-[:PEAKS_DURING]->(s:Seasonality)
# WITH d, collect(s.id) AS seasons
# WHERE size(seasons) > 2
# RETURN d.id AS Disease, seasons
#
# Full Context:
# [{'Disease': 'Durian Leaf Anthracnose', 'seasons': ['Rainy/Monsoon Season', 'May To October In Thailand And Vietnam', 'Late-Year Monsoons In Malaysia']}]
#
# > Finished chain.
# {'query': 'Bệnh nào xuất hiện của nhiều hơn 2 mùa trong năm và đó là những mùa nào?',
#  'result': 'Bệnh Durian Leaf Anthracnose xuất hiện trong nhiều hơn 2 mùa trong năm, đó là mùa mưa/monsoon, từ tháng 5 đến tháng 10 ở Thái Lan và Việt Nam, và các đợt gió mùa cuối năm ở Malaysia.'}

# %%
response = chain.invoke({"query": "Mùa mưa thường xuất hiện bệnh nào?"})
response
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (d:Disease)-[:PEAKS_DURING]->(s:Seasonality {id: 'Monsoon Or Rainy Season'})
# RETURN d.id
#
# Full Context:
# [{'d.id': 'Pink Disease'}]
#
# > Finished chain.
# {'query': 'Mùa mưa thường xuất hiện bệnh nào?',
#  'result': 'Bệnh thường xuất hiện trong mùa mưa là bệnh Pink Disease.'}

# %%
response = chain.invoke({"query": "Bệnh nào xuất hiện ở nhiều bộ phận trên cây nhất, đó là những bộ phận nào?"})
response
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (c:Crop)-[:AFFECTED_BY]->(d:Disease), (c)-[:HAS_CROP_PART]->(cp:Crop_part)
# RETURN d.id AS Disease, collect(DISTINCT cp.id) AS CropParts, count(DISTINCT cp) AS NumberOfParts
# ORDER BY NumberOfParts DESC
# LIMIT 1
#
# Full Context:
# [{'Disease': 'Phomopsis Leaf Blight', 'CropParts': ['Young Fruits', 'Flowers', 'Shoots', 'Branches', 'Stem', 'Trunk', 'Fruit', 'Stems/Trunk', 'Roots', 'Leaves'], 'NumberOfParts': 10}]
#
# > Finished chain.
# {'query': 'Bệnh nào xuất hiện ở nhiều bộ phận trên cây nhất, đó là những bộ phận nào?',
#  'result': 'Bệnh Phomopsis Leaf Blight xuất hiện ở nhiều bộ phận trên cây nhất, đó là Young Fruits, Flowers, Shoots, Branches, Stem, Trunk, Fruit, Stems/Trunk, Roots, Leaves.'}

# %%
response = chain.invoke({"query": "Có những Bộ phận nào trên cây sầu riêng, và bộ phần nào có nhiều disease nhất?"})
response
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# cypher
# MATCH (c:Crop {id: 'Durian'})-[:HAS_CROP_PART]->(cp:Crop_part)
# OPTIONAL MATCH (cp)-[:HAS_SYMPTOM]->(:Symptom)<-[:AFFECTED_BY]-(c)-[:AFFECTED_BY]->(d:Disease)
# RETURN cp.id AS CropPart, COUNT(d) AS DiseaseCount
# ORDER BY DiseaseCount DESC
#
# Full Context:
# [{'CropPart': 'Young Fruits', 'DiseaseCount': 0}, {'CropPart': 'Flowers', 'DiseaseCount': 0}, {'CropPart': 'Shoots', 'DiseaseCount': 0}, {'CropPart': 'Branches', 'DiseaseCount': 0}, {'CropPart': 'Stem', 'DiseaseCount': 0}, {'CropPart': 'Trunk', 'DiseaseCount': 0}, {'CropPart': 'Fruit', 'DiseaseCount': 0}, {'CropPart': 'Stems/Trunk', 'DiseaseCount': 0}, {'CropPart': 'Roots', 'DiseaseCount': 0}, {'CropPart': 'Leaves', 'DiseaseCount': 0}]
#
# > Finished chain.
# {'query': 'Có những Bộ phận nào trên cây sầu riêng, và bộ phần nào có nhiều disease nhất?',
#  'result': 'Trên cây sầu riêng có các bộ phận: Trái non, Hoa, Chồi, Cành, Thân, Thân cây, Trái, Thân/Thân cây, Rễ, và Lá. Không có bộ phận nào có nhiều bệnh nhất vì tất cả đều có số lượng bệnh là 0.'}
