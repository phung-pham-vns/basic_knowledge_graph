# %%
import textwrap
import langextract as lx

# 1. Define a concise prompt
prompt = textwrap.dedent("""Extract characters, emotions, and relationships in order of appearance. Use exact text for extractions. Do not paraphrase or overlap entities. Provide meaningful attributes for each entity to add context.""")

# 2. Provide a high-quality example to guide the model
examples = [
    lx.data.ExampleData(
        text=(
            "ROMEO. But soft! What light through yonder window breaks? It is the east, and Juliet is the sun."
        ),
        extractions=[
            lx.data.Extraction(
                extraction_class="character",
                extraction_text="ROMEO",
                attributes={"emotional_state": "wonder"},
            ),
            lx.data.Extraction(
                extraction_class="emotion",
                extraction_text="But soft!",
                attributes={"feeling": "gentle awe"},
            ),
            lx.data.Extraction(
                extraction_class="relationship",
                extraction_text="Juliet is the sun",
                attributes={"type": "metaphor"},
            ),
        ],
    )
]

# 3. Run the extraction on your input text
input_text = (
    "Lady Juliet gazed longingly at the stars, her heart aching for Romeo"
)
result = lx.extract(
    api_key="AIzaSyDuE2meWEZ22quM3ef84DjHDmByYOpvb3Y",
    model_id="gemini-2.5-flash",
    text_or_documents=input_text,
    prompt_description=prompt,
    examples=examples,
)
# Out:
# 2025-08-26 14:21:00,638 - langextract.debug - DEBUG - [langextract.inference] CALL: BaseLanguageModel.__init__(self=<GeminiLanguageModel>, constraint=Constraint(co...NONE: 'none'>), kwargs={})
# 2025-08-26 14:21:00,639 - langextract.debug - DEBUG - [langextract.inference] RETURN: BaseLanguageModel.__init__ -> None (0.0 ms)
# 2025-08-26 14:21:00,639 - langextract.debug - DEBUG - [langextract.inference] CALL: BaseLanguageModel.apply_schema(self=<GeminiLanguageModel>, schema_instance=GeminiSchema(...xtractions']}))
# 2025-08-26 14:21:00,639 - langextract.debug - DEBUG - [langextract.inference] RETURN: BaseLanguageModel.apply_schema -> None (0.0 ms)
# DEBUG:absl:Initialized Annotator with prompt:
# Extract characters, emotions, and relationships in order of appearance. Use exact text for extractions. Do not paraphrase or overlap entities. Provide meaningful attributes for each entity to add context.
#
# Examples
# Q: ROMEO. But soft! What light through yonder window breaks? It is the east, and Juliet is the sun.
# A: {
#   "extractions": [
#     {
#       "character": "ROMEO",
#       "character_attributes": {
#         "emotional_state": "wonder"
#       }
#     },
#     {
#       "emotion": "But soft!",
#       "emotion_attributes": {
#         "feeling": "gentle awe"
#       }
#     },
#     {
#       "relationship": "Juliet is the sun",
#       "relationship_attributes": {
#         "type": "metaphor"
#       }
#     }
#   ]
# }
#
# Q:
# A:
# INFO:absl:Starting document annotation.
# LangExtract: model=gemini-2.5-flash [00:00]2025-08-26 14:21:00,641 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo')
# 2025-08-26 14:21:00,641 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# INFO:absl:Processing batch 0 with length 1
# DEBUG:absl:Token util returns string: Lady Juliet gazed longingly at the stars, her heart aching for Romeo for tokenized_text: TokenizedText(text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo', tokens=[Token(index=0, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=0, end_pos=4), first_token_after_newline=False), Token(index=1, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=5, end_pos=11), first_token_after_newline=False), Token(index=2, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=12, end_pos=17), first_token_after_newline=False), Token(index=3, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=18, end_pos=27), first_token_after_newline=False), Token(index=4, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=28, end_pos=30), first_token_after_newline=False), Token(index=5, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=31, end_pos=34), first_token_after_newline=False), Token(index=6, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=35, end_pos=40), first_token_after_newline=False), Token(index=7, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=40, end_pos=41), first_token_after_newline=False), Token(index=8, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=42, end_pos=45), first_token_after_newline=False), Token(index=9, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=46, end_pos=51), first_token_after_newline=False), Token(index=10, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=52, end_pos=58), first_token_after_newline=False), Token(index=11, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=59, end_pos=62), first_token_after_newline=False), Token(index=12, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=63, end_pos=68), first_token_after_newline=False)]), token_interval: TokenInterval(start_index=0, end_index=13)
# LangExtract: model=gemini-2.5-flash, current=68 chars, processed=68 chars:  [00:00]DEBUG:absl:Processing chunk: TextChunk(
#   interval=[start_index: 0, end_index: 13],
#   Document ID: doc_8226af7d,
#   Chunk Text: 'Lady Juliet gazed longingly at the stars, her heart aching for Romeo'
# )
# DEBUG:absl:Top inference result: {
#   "extractions": [
#     {
#       "character": "Lady Juliet",
#       "character_attributes": {
#         "emotional_state": "longing"
#       }
#     },
#     {
#       "emotion": "gazed longingly",
#       "emotion_attributes": {
#         "feeling": "desire"
#       }
#     },
#     {
#       "emotion": "her heart aching",
#       "emotion_attributes": {
#         "feeling": "sorrow"
#       }
#     },
#     {
#       "relationship": "for Romeo",
#       "relationship_attributes": {
#         "type": "romantic interest"
#       }
#     }
#   ]
# }
# INFO:absl:Starting resolver process for input text.
# DEBUG:absl:Input Text: {
#   "extractions": [
#     {
#       "character": "Lady Juliet",
#       "character_attributes": {
#         "emotional_state": "longing"
#       }
#     },
#     {
#       "emotion": "gazed longingly",
#       "emotion_attributes": {
#         "feeling": "desire"
#       }
#     },
#     {
#       "emotion": "her heart aching",
#       "emotion_attributes": {
#         "feeling": "sorrow"
#       }
#     },
#     {
#       "relationship": "for Romeo",
#       "relationship_attributes": {
#         "type": "romantic interest"
#       }
#     }
#   ]
# }
# INFO:absl:Starting string parsing.
# DEBUG:absl:input_string: {
#   "extractions": [
#     {
#       "character": "Lady Juliet",
#       "character_attributes": {
#         "emotional_state": "longing"
#       }
#     },
#     {
#       "emotion": "gazed longingly",
#       "emotion_attributes": {
#         "feeling": "desire"
#       }
#     },
#     {
#       "emotion": "her heart aching",
#       "emotion_attributes": {
#         "feeling": "sorrow"
#       }
#     },
#     {
#       "relationship": "for Romeo",
#       "relationship_attributes": {
#         "type": "romantic interest"
#       }
#     }
#   ]
# }
# DEBUG:absl:Successfully parsed content.
# INFO:absl:Completed parsing of string.
# DEBUG:absl:Parsed content: [{'character': 'Lady Juliet', 'character_attributes': {'emotional_state': 'longing'}}, {'emotion': 'gazed longingly', 'emotion_attributes': {'feeling': 'desire'}}, {'emotion': 'her heart aching', 'emotion_attributes': {'feeling': 'sorrow'}}, {'relationship': 'for Romeo', 'relationship_attributes': {'type': 'romantic interest'}}]
# INFO:absl:Starting to extract and order extractions from data.
# INFO:absl:Completed extraction and ordering of extractions.
# DEBUG:absl:Completed the resolver process.
# INFO:absl:Starting alignment process for provided chunk text.
# DEBUG:absl:WordAligner: Starting alignment of extractions with the source text. Extraction groups to align: [[Extraction(extraction_class='character', extraction_text='Lady Juliet', char_interval=None, alignment_status=None, extraction_index=1, group_index=0, description=None, attributes={'emotional_state': 'longing'}), Extraction(extraction_class='emotion', extraction_text='gazed longingly', char_interval=None, alignment_status=None, extraction_index=2, group_index=1, description=None, attributes={'feeling': 'desire'}), Extraction(extraction_class='emotion', extraction_text='her heart aching', char_interval=None, alignment_status=None, extraction_index=3, group_index=2, description=None, attributes={'feeling': 'sorrow'}), Extraction(extraction_class='relationship', extraction_text='for Romeo', char_interval=None, alignment_status=None, extraction_index=4, group_index=3, description=None, attributes={'type': 'romantic interest'})]]
# 2025-08-26 14:21:04,639 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo')
# 2025-08-26 14:21:04,640 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-26 14:21:04,640 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='␟')
# 2025-08-26 14:21:04,640 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# DEBUG:absl:Using delimiter '␟' for extraction alignment
# 2025-08-26 14:21:04,640 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet ␟ gazed longingly ␟ her heart aching ␟ for Romeo')
# 2025-08-26 14:21:04,641 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# DEBUG:absl:Processing extraction group 0 with 4 extractions.
# 2025-08-26 14:21:04,641 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet')
# 2025-08-26 14:21:04,641 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-26 14:21:04,642 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='gazed longingly')
# 2025-08-26 14:21:04,642 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-26 14:21:04,642 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='her heart aching')
# 2025-08-26 14:21:04,642 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-26 14:21:04,642 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='for Romeo')
# 2025-08-26 14:21:04,643 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-26 14:21:04,643 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo')
# 2025-08-26 14:21:04,644 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-26 14:21:04,644 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet')
# 2025-08-26 14:21:04,644 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-26 14:21:04,644 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='gazed longingly')
# 2025-08-26 14:21:04,644 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-26 14:21:04,645 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='her heart aching')
# 2025-08-26 14:21:04,645 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-26 14:21:04,645 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='for Romeo')
# 2025-08-26 14:21:04,645 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# DEBUG:absl:Final aligned extraction groups: [[Extraction(extraction_class='character', extraction_text='Lady Juliet', char_interval=CharInterval(start_pos=0, end_pos=11), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'emotional_state': 'longing'}), Extraction(extraction_class='emotion', extraction_text='gazed longingly', char_interval=CharInterval(start_pos=12, end_pos=27), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'feeling': 'desire'}), Extraction(extraction_class='emotion', extraction_text='her heart aching', char_interval=CharInterval(start_pos=42, end_pos=58), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'feeling': 'sorrow'}), Extraction(extraction_class='relationship', extraction_text='for Romeo', char_interval=CharInterval(start_pos=59, end_pos=68), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'type': 'romantic interest'})]]
# DEBUG:absl:Aligned extractions count: 4
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='character', extraction_text='Lady Juliet', char_interval=CharInterval(start_pos=0, end_pos=11), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'emotional_state': 'longing'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='emotion', extraction_text='gazed longingly', char_interval=CharInterval(start_pos=12, end_pos=27), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'feeling': 'desire'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='emotion', extraction_text='her heart aching', char_interval=CharInterval(start_pos=42, end_pos=58), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'feeling': 'sorrow'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='relationship', extraction_text='for Romeo', char_interval=CharInterval(start_pos=59, end_pos=68), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'type': 'romantic interest'})
# INFO:absl:Completed alignment process for the provided source_text.
# LangExtract: model=gemini-2.5-flash, current=68 chars, processed=68 chars:  [00:04]
# ✓ Extraction processing complete
# INFO:absl:Finalizing annotation for document ID doc_8226af7d.
# INFO:absl:Document annotation completed.
# ✓ Extracted 4 entities (3 unique types)
#   • Time: 4.01s
#   • Speed: 17 chars/sec
#   • Chunks: 1

# %%
result
# Out:
# AnnotatedDocument(extractions=[Extraction(extraction_class='character', extraction_text='Lady Juliet', char_interval=CharInterval(start_pos=0, end_pos=11), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'emotional_state': 'longing'}), Extraction(extraction_class='emotion', extraction_text='gazed longingly', char_interval=CharInterval(start_pos=12, end_pos=27), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'feeling': 'desire'}), Extraction(extraction_class='emotion', extraction_text='her heart aching', char_interval=CharInterval(start_pos=42, end_pos=58), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'feeling': 'sorrow'}), Extraction(extraction_class='relationship', extraction_text='for Romeo', char_interval=CharInterval(start_pos=59, end_pos=68), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'type': 'romantic interest'})], text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo')
